# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # loading the data sets

# %%
df_19 = pd.read_csv('2019.csv')
df_19.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
#creating a copy of the initial data set 
df_copy = df_19.copy()
df_copy.shape
# Out:
# (156, 9)

# %%
#checking out if the data has any missing values
df_19.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# We can see that there are no missing values in this dataset

# %%
#getting the info of the data
df_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df_19.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
#doing some visualisation and analyse the data

# %%
#checking out the correlation between variables

df_19_corr= df_19.corr()
df_19_corr
# Out:
#                               Overall rank     Score  GDP per capita  \
# Overall rank                      1.000000 -0.989096       -0.801947
# Score                            -0.989096  1.000000        0.793883
# GDP per capita                   -0.801947  0.793883        1.000000
# Social support                   -0.767465  0.777058        0.754906
# Healthy life expectancy          -0.787411  0.779883        0.835462
# Freedom to make life choices     -0.546606  0.566742        0.379079
# Generosity                       -0.047993  0.075824       -0.079662
# Perceptions of corruption        -0.351959  0.385613        0.298920
#
#                               Social support  Healthy life expectancy  \
# Overall rank                       -0.767465                -0.787411
# Score                               0.777058                 0.779883
# GDP per capita                      0.754906                 0.835462
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_19_corr,annot=True,square=True)
plt.show()

# %%
#univariate analysis
for i in df_19.columns:
    if i != 'Country or region':
        plt.figure(figsize=(5,3))
        sns.distplot(df_19[i])
        plt.show()

# %%
for i in df_19.columns:
    if i != 'Country or region':
        plt.figure(figsize=(6,5))
        sns.scatterplot(df_19[i],df_19['Score'])
        plt.show()

# %% [markdown]
# with the refrence of the above plots it can be seen that some factors like GDP,Social Support, Healthy life expectancy, freedom to make life choices are highly correlated with the score

# %%
#lets make a pairplot for multivariate analysis
plt.figure(figsize=(10,8))
sns.pairplot(df_19)
plt.show()

# %%
df_19.loc[df_19['Country or region'] == 'India']
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 139           140             India  4.015           0.755           0.765
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 139                    0.588                         0.498         0.2
#
#      Perceptions of corruption
# 139                      0.085

# %%
#rank of our country is 140 as per the report of year 2019. We still have a long way to go. 

#lets compare the rank with top 20 countries

df_19.loc[df_19['Overall rank'] <= 20]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 0              1           Finland  7.769           1.340           1.587
# 1              2           Denmark  7.600           1.383           1.573
# 2              3            Norway  7.554           1.488           1.582
# 3              4           Iceland  7.494           1.380           1.624
# 4              5       Netherlands  7.488           1.396           1.522
# 5              6       Switzerland  7.480           1.452           1.526
# 6              7            Sweden  7.343           1.387           1.487
# 7              8       New Zealand  7.307           1.303           1.557
# 8              9            Canada  7.278           1.365           1.505
# 9             10           Austria  7.246           1.376           1.475
# 10            11         Australia  7.228           1.372           1.548
# 11            12        Costa Rica  7.167           1.034           1.441
# ...

# %% [markdown]
# comparing rank with our neigbour countries, to check if we are doing bettr from them
# India shares borders with several sovereign countries; it shares land borders with China, Bhutan, Nepal, Pakistan and Afghanistan in the north or north-west, and with Bangladesh and Myanmar in the east. India also shares water borders with Sri Lanka, Maldives and Indonesia

# %%
df_19.loc[df_19['Country or region'] == 'China']
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 92            93             China  5.191           1.029           1.125
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                    0.893                         0.521       0.058
#
#     Perceptions of corruption
# 92                        0.1

# %%
df_19.loc[df_19['Country or region'] == 'Bhutan']
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 94            95            Bhutan  5.082           0.813           1.321
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 94                    0.604                         0.457        0.37
#
#     Perceptions of corruption
# 94                      0.167

# %%
df_19.loc[df_19['Country or region'] == 'Nepal']
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 99           100             Nepal  4.913           0.446           1.226
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 99                    0.677                         0.439       0.285
#
#     Perceptions of corruption
# 99                      0.089

# %%
df_19.loc[df_19['Country or region'] == 'Pakistan']
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 66            67          Pakistan  5.653           0.677           0.886
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 66                    0.535                         0.313        0.22
#
#     Perceptions of corruption
# 66                      0.098

# %%
df_19.loc[df_19['Country or region'] == 'Afghanistan']
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 153           154       Afghanistan  3.203            0.35           0.517
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 153                    0.361                           0.0       0.158
#
#      Perceptions of corruption
# 153                      0.025

# %%
df_19.loc[df_19['Country or region'] == 'Bangladesh']
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 124           125        Bangladesh  4.456           0.562           0.928
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 124                    0.723                         0.527       0.166
#
#      Perceptions of corruption
# 124                      0.143

# %%
df_19.loc[df_19['Country or region'] == 'Myanmar']
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 130           131           Myanmar   4.36            0.71           1.181
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 130                    0.555                         0.525       0.566
#
#      Perceptions of corruption
# 130                      0.172

# %%
df_19.loc[df_19['Country or region'] == 'Sri Lanka']
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 129           130         Sri Lanka  4.366           0.949           1.265
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 129                    0.831                          0.47       0.244
#
#      Perceptions of corruption
# 129                      0.047

# %%
df_19.loc[df_19['Country or region'] == 'Maldives']
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
df_19.loc[df_19['Country or region'] == 'Indonesia']
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 91            92         Indonesia  5.192           0.931           1.203
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 91                     0.66                         0.491       0.498
#
#     Perceptions of corruption
# 91                      0.028

# %%
Ncomparison = df_19[(df_19['Country or region'].isin(['India','China', 'Bhutan', 'Nepal', 'Pakistan','Afghanistan','Bangladesh','Indonesia','Sri Lanka','Myanmar']))]
Ncomparison
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 66             67          Pakistan  5.653           0.677           0.886
# 91             92         Indonesia  5.192           0.931           1.203
# 92             93             China  5.191           1.029           1.125
# 94             95            Bhutan  5.082           0.813           1.321
# 99            100             Nepal  4.913           0.446           1.226
# 124           125        Bangladesh  4.456           0.562           0.928
# 129           130         Sri Lanka  4.366           0.949           1.265
# 130           131           Myanmar  4.360           0.710           1.181
# 139           140             India  4.015           0.755           0.765
# 153           154       Afghanistan  3.203           0.350           0.517
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %%
#now we wil compare visually the scoring factors of the above countries.

Ncomparison.plot(kind='bar',x='Country or region',y='GDP per capita')
Ncomparison.plot(kind='bar',x='Country or region',y='Social support')
Ncomparison.plot(kind='bar',x='Country or region',y='Healthy life expectancy')
Ncomparison.plot(kind='bar',x='Country or region',y='Freedom to make life choices')
plt.show()

# %%
plt.figure(figsize=(20,20))
ax = Ncomparison.plot(kind='bar',x='Country or region',y='Social support',color='C1')
Ncomparison.plot(kind='bar',x='Country or region',y='GDP per capita',ax=ax,color='C3')
Ncomparison.plot(kind='bar',x='Country or region',y='Healthy life expectancy',ax=ax,color='C2')
Ncomparison.plot(kind='bar',x='Country or region',y='Freedom to make life choices',ax=ax,color='C4')
plt.show()

# %% [markdown]
# with the above graph, we can see that India Lacks in social suport Factor and it also shows the freedonm of making choice in afganistan is null

# %%
plt.figure(figsize=(20,20))
ax = Ncomparison.plot(kind='line',x='Country or region',y='Social support',color='C1')
Ncomparison.plot(kind='line',x='Country or region',y='GDP per capita',ax=ax,color='C3')
Ncomparison.plot(kind='line',x='Country or region',y='Healthy life expectancy',ax=ax,color='C2')
Ncomparison.plot(kind='line',x='Country or region',y='Freedom to make life choices',ax=ax,color='C4')
plt.show()

# %% [markdown]
# Lets see top 10 countries for each independent feature

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,constrained_layout=True,figsize=(13,9))
sns.barplot(x='GDP per capita',y='Country or region',data=df_19.nlargest(10,'GDP per capita'),ax=axes[0,0],palette="Blues_d")
sns.barplot(x='Social support' ,y='Country or region',data=df_19.nlargest(10,'Social support'),ax=axes[0,1],palette="YlGn")
sns.barplot(x='Healthy life expectancy' ,y='Country or region',data=df_19.nlargest(10,'Healthy life expectancy'),ax=axes[1,0],palette='OrRd')
sns.barplot(x='Freedom to make life choices' ,y='Country or region',data=df_19.nlargest(10,'Freedom to make life choices'),ax=axes[1,1],palette='YlOrBr')
sns.barplot(x='Perceptions of corruption',y='Country or region',data=df_19.nlargest(10,'Perceptions of corruption'),ax=axes[2,0],palette="rocket_r")
sns.barplot(x='Generosity',y='Country or region',data=df_19.nlargest(10,'Generosity'),ax=axes[2,1],palette="viridis")
plt.show()

# %%
fac_col = ['GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Perceptions of corruption','Generosity']
for i in fac_col:
    sns.barplot(x=i,y='Country or region',data=df_19.nlargest(10,i))
    plt.show()

# %%
#loading of previous years world happiness report data so that we can check
#what changes were happen, and what were the change in features over the years.

# %%
df_15 = pd.read_csv('2015.csv')
df_15.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_16 = pd.read_csv('2016.csv')
df_16.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_17 = pd.read_csv('2017.csv')
df_17.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df_18 = pd.read_csv('2018.csv')
df_18.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %% [markdown]
# we can see that the common input features in all the data sets are [Country or region,GDP per capita,Social support,Healthy life expectancy,Freedom to make life choices,Perceptions of corruption]
# we will check the difference in these inputs over the years from 2015 to 2019

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(15,12))
sns.kdeplot(df_15['Economy (GDP per Capita)'],ax=axes[0,0],color='blue')
sns.kdeplot(df_16['Economy (GDP per Capita)'],ax=axes[0,0],color='red')
sns.kdeplot(df_17['Economy..GDP.per.Capita.'],ax=axes[0,0],color='green')
sns.kdeplot(df_18['GDP per capita'],ax=axes[0,0],color='yellow')
sns.kdeplot(df_19['GDP per capita'],ax=axes[0,0],color='black')

sns.kdeplot(df_15['Family'],ax=axes[0,1],color='blue')
sns.kdeplot(df_16['Family'],ax=axes[0,1],color='red')
sns.kdeplot(df_17['Family'],ax=axes[0,1],color='green')
sns.kdeplot(df_18['Social support'],ax=axes[0,1],color='yellow')
sns.kdeplot(df_19['Social support'],ax=axes[0,1],color='black')

sns.kdeplot(df_15['Health (Life Expectancy)'],ax=axes[1,0],color='blue')
sns.kdeplot(df_16['Health (Life Expectancy)'],ax=axes[1,0],color='red')
sns.kdeplot(df_17['Health..Life.Expectancy.'],ax=axes[1,0],color='green')
sns.kdeplot(df_18['Healthy life expectancy'],ax=axes[1,0],color='yellow')
sns.kdeplot(df_19['Healthy life expectancy'],ax=axes[1,0],color='black')

sns.kdeplot(df_15['Freedom'],ax=axes[1,1],color='blue')
sns.kdeplot(df_16['Freedom'],ax=axes[1,1],color='red')
sns.kdeplot(df_17['Freedom'],ax=axes[1,1],color='green')
sns.kdeplot(df_18['Freedom to make life choices'],ax=axes[1,1],color='yellow')
sns.kdeplot(df_19['Freedom to make life choices'],ax=axes[1,1],color='black')

sns.kdeplot(df_15['Trust (Government Corruption)'],ax=axes[2,0],color='blue')
sns.kdeplot(df_16['Trust (Government Corruption)'],ax=axes[2,0],color='red')
sns.kdeplot(df_17['Trust..Government.Corruption.'],ax=axes[2,0],color='green')
sns.kdeplot(df_18['Perceptions of corruption'],ax=axes[2,0],color='yellow')
sns.kdeplot(df_19['Perceptions of corruption'],ax=axes[2,0],color='black')

sns.kdeplot(df_15['Generosity'],ax=axes[2,1],color='blue')
sns.kdeplot(df_16['Generosity'],ax=axes[2,1],color='red')
sns.kdeplot(df_17['Generosity'],ax=axes[2,1],color='green')
sns.kdeplot(df_18['Generosity'],ax=axes[2,1],color='yellow')
sns.kdeplot(df_19['Generosity'],ax=axes[2,1],color='black')


plt.show()

# %%
#lets see the changes of all the input factors over the years for our country

# %%
df_15.loc[df_15['Country'] == 'India']['Economy (GDP per Capita)']
# Out:
# 116    0.64499
# Name: Economy (GDP per Capita), dtype: float64

# %%
df_16.loc[df_16['Country'] == 'India']['Economy (GDP per Capita)']
# Out:
# 117    0.74036
# Name: Economy (GDP per Capita), dtype: float64

# %%
df_17.loc[df_17['Country'] == 'India']['Economy..GDP.per.Capita.']
# Out:
# 121    0.792221
# Name: Economy..GDP.per.Capita., dtype: float64

# %%
df_18.loc[df_18['Country or region'] == 'India']['GDP per capita']
# Out:
# 132    0.721
# Name: GDP per capita, dtype: float64

# %%
df_19.loc[df_19['Country or region'] == 'India']['GDP per capita']
# Out:
# 139    0.755
# Name: GDP per capita, dtype: float64

# %% [markdown]
# with the above data we can see that the India's Economy dipped alot in year 2018, it was highest in year 2017 and in 2019 is it is recovering

# %%
#creating a new attribute 'Year' 
df_15['Year']='2015'
df_16['Year']='2016'
df_17['Year']='2017'
df_18['Year']='2018'
df_19['Year']='2019'

# %%
#creating a new data frame for GDP, year and country. We will compare our Economy with our neighbor countries

#we have to rearrange the columns is similar format for the data between 2015-2019

df_15.rename(columns={'Economy (GDP per Capita)':'GDP per capita'},inplace=True)
data15=df_15.filter(['Country','GDP per capita','Year'],axis=1)

df_16.rename(columns={'Economy (GDP per Capita)':'GDP per capita'},inplace=True)
data16 = df_16.filter(['Country','GDP per capita','Year'],axis=1)

df_17.rename(columns={'Economy..GDP.per.Capita.':'GDP per capita'},inplace=True)
data17= df_17.filter(['Country','GDP per capita','Year'],axis=1)

df_18.rename(columns={'Country or region': 'Country'},inplace=True)
data18 = df_18.filter(['Country','GDP per capita','Year'],axis=1)

df_19.rename(columns={'Country or region': 'Country'},inplace=True)
data19 = df_19.filter(['Country','GDP per capita','Year'],axis=1)

# %%
#appending data15,data16,data17.data18 and data19

data = data15.append([data16,data17,data18,data19])
data.head()
# Out:
#        Country  GDP per capita  Year
# 0  Switzerland         1.39651  2015
# 1      Iceland         1.30232  2015
# 2      Denmark         1.32548  2015
# 3       Norway         1.45900  2015
# 4       Canada         1.32629  2015

# %%
data.tail()
# Out:
#                       Country  GDP per capita  Year
# 151                    Rwanda           0.359  2019
# 152                  Tanzania           0.476  2019
# 153               Afghanistan           0.350  2019
# 154  Central African Republic           0.026  2019
# 155               South Sudan           0.306  2019

# %%
plt.figure(figsize=(10,8))
df = data[data['Country']=='India']
sns.lineplot(x="Year", y="GDP per capita",data=df,label='India')

df = data[data['Country']=='Pakistan']
sns.lineplot(x="Year", y="GDP per capita",data=df,label='Pakistan')

df = data[data['Country']=='China']
sns.lineplot(x="Year", y="GDP per capita",data=df,label='China')

df = data[data['Country']=='Nepal']
sns.lineplot(x="Year", y="GDP per capita",data=df,label='Nepal')

df = data[data['Country']=='Bhutan']
sns.lineplot(x="Year", y="GDP per capita",data=df,label='Bhutan')

df = data[data['Country']=='Bangladesh']
sns.lineplot(x="Year", y="GDP per capita",data=df,label='Bangladesh')

df = data[data['Country']=='Myanmar']
sns.lineplot(x="Year", y="GDP per capita",data=df,label='Myanmar')

df = data[data['Country']=='Sri Lanka']
sns.lineplot(x="Year", y="GDP per capita",data=df,label='Sri Lanka')

df = data[data['Country']=='Indonesia']
sns.lineplot(x="Year", y="GDP per capita",data=df,label='Indonesia')

plt.show()

# %% [markdown]
# Looking at the GDP growth of Myanmar, it is rising from 2015 and a great hike in 2017-2018

# %%
#lloking for Happiness score over the years

df_15.rename(columns={'Happiness Score':'Score'},inplace=True)
data15_s=df_15.filter(['Country','Score','Year'],axis=1)

df_16.rename(columns={'Happiness Score':'Score'},inplace=True)
data16_s = df_16.filter(['Country','Score','Year'],axis=1)

df_17.rename(columns={'Happiness.Score.':'Score'},inplace=True)
data17_s= df_17.filter(['Country','Score','Year'],axis=1)

df_18.rename(columns={'Country or region': 'Country'},inplace=True)
data18_s = df_18.filter(['Country','Score','Year'],axis=1)

df_19.rename(columns={'Country or region': 'Country'},inplace=True)
data19_s = df_19.filter(['Country','Score','Year'],axis=1)

# %%
data_s = data15_s.append([data16_s,data17_s,data18_s,data19_s])

data_s.head()
# Out:
#        Country  Score  Year
# 0  Switzerland  7.587  2015
# 1      Iceland  7.561  2015
# 2      Denmark  7.527  2015
# 3       Norway  7.522  2015
# 4       Canada  7.427  2015

# %%
data_s.tail()
# Out:
#                       Country  Score  Year
# 151                    Rwanda  3.334  2019
# 152                  Tanzania  3.231  2019
# 153               Afghanistan  3.203  2019
# 154  Central African Republic  3.083  2019
# 155               South Sudan  2.853  2019

# %%
plt.figure(figsize=(10,8))
df = data_s[data_s['Country']=='India']
sns.lineplot(x="Year", y="Score",data=df,label='India')

df = data_s[data_s['Country']=='Pakistan']
sns.lineplot(x="Year", y="Score",data=df,label='Pakistan')

df = data_s[data_s['Country']=='China']
sns.lineplot(x="Year", y="Score",data=df,label='China')

df = data_s[data_s['Country']=='Nepal']
sns.lineplot(x="Year", y="Score",data=df,label='Nepal')

df = data_s[data_s['Country']=='Bhutan']
sns.lineplot(x="Year", y="Score",data=df,label='Bhutan')

df = data_s[data_s['Country']=='Bangladesh']
sns.lineplot(x="Year", y="Score",data=df,label='Bangladesh')

df = data_s[data_s['Country']=='Myanmar']
sns.lineplot(x="Year", y="Score",data=df,label='Myanmar')

df = data_s[data_s['Country']=='Sri Lanka']
sns.lineplot(x="Year", y="Score",data=df,label='Sri Lanka')

df = data_s[data_s['Country']=='Indonesia']
sns.lineplot(x="Year", y="Score",data=df,label='Indonesia')

plt.xlabel("Years")
plt.ylabel("Score")
plt.show()

# %% [markdown]
# sad to see that

# %% [markdown]
# splitting data into inputs and target features

# %%
df_19.columns
# Out:
# Index(['Overall rank', 'Country', 'Score', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Year'],
#       dtype='object')

# %%
X = df_19.drop(columns=['Country','Score','Overall rank','Year'])
X.shape
# Out:
# (156, 6)

# %%
X.head()
# Out:
#    GDP per capita  Social support  Healthy life expectancy  \
# 0           1.340           1.587                    0.986
# 1           1.383           1.573                    0.996
# 2           1.488           1.582                    1.028
# 3           1.380           1.624                    1.026
# 4           1.396           1.522                    0.999
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.596       0.153                      0.393
# 1                         0.592       0.252                      0.410
# 2                         0.603       0.271                      0.341
# 3                         0.591       0.354                      0.118
# 4                         0.557       0.322                      0.298

# %%
y = df_19['Score']
y.shape
# Out:
# (156,)

# %%
#using standard sclaer in input features

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_sc = sc.fit_transform(X)

X_scdf = pd.DataFrame(X_sc)

# %%
X_scdf.head()
# Out:
#           0         1         2         3         4         5
# 0  1.095042  1.268098  1.080422  1.424282 -0.335404  2.996757
# 1  1.203324  1.221154  1.121857  1.396277  0.707265  3.177158
# 2  1.467734  1.251332  1.254446  1.473292  0.907373  2.444941
# 3  1.195769  1.392163  1.246159  1.389276  1.781530  0.078500
# 4  1.236060  1.050146  1.134287  1.151229  1.444506  1.988632

# %%
#splitting data into train and test

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
max_lr_score = 0
for r_state in range(41,100):
    X_train,x_test,y_train,y_test= train_test_split(X,y,test_size=.33,random_state=r_state)
    lr = LinearRegression()
    lr.fit(X_train,y_train)
    lr_pred = lr.predict(x_test)
    r2_scr = r2_score(y_test,lr_pred)
    if r2_scr>max_lr_score:
        max_lr_score=r2_scr
        final_r_state = r_state
        
print('max r2_score for the given ','', final_r_state, 'is', max_lr_score)
# Out:
# max r2_score for the given   80 is 0.8398085284356338

# %%
#creating a model using Linear Regression
X_train,x_test,y_train,y_test= train_test_split(X,y,test_size=.33,random_state=80)
print('X_train shape:', X_train.shape)
print('x_test shape:', x_test.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (104, 6)
# x_test shape: (52, 6)
# y_train shape: (104,)
# y_test shape: (52,)

# %%
lr = LinearRegression()

# %%
model = lr.fit(X_train,y_train)
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred = lr.predict(x_test)
pred
# Out:
# array([5.44986662, 5.20854777, 5.66198447, 4.07914654, 5.57612386,
#        7.00048556, 5.99329413, 7.11247831, 6.64827907, 4.87496917,
#        4.26845691, 6.70139708, 4.31896311, 6.22603781, 6.58582952,
#        6.42231743, 3.96790697, 5.70142386, 6.14266418, 3.3056378 ,
#        6.09266369, 4.94615864, 3.91103999, 6.37457268, 5.68337958,
#        6.63847576, 5.46807871, 4.8205539 , 5.36361509, 5.32848219,
#        6.4133647 , 5.46794987, 6.34751124, 5.93649647, 6.97482452,
#        5.74581299, 4.93503298, 5.55958473, 6.01796724, 3.25314823,
#        5.25615325, 5.85202345, 5.70894389, 3.62316821, 4.32646603,
#        5.49208761, 5.13645135, 5.50129316, 4.97082073, 6.91878234,
#        5.60793086, 6.21563166])

# %%
R2_score = r2_score(y_test,pred)
R2_score
# Out:
# 0.8398085284356338

# %%
MSE = mean_squared_error(y_test,pred)
MSE
# Out:
# 0.1776267113294318

# %%
MAE = mean_absolute_error(y_test,pred)
MAE
# Out:
# 0.3495139548387402

# %%
import math
from math import sqrt

# %%
RMSE = sqrt(MSE)
RMSE
# Out:
# 0.4214578405124667

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
#using Random forest regressor

max_rf_score = 0
for r_state in range(41,100):
    X_train,x_test,y_train,y_test= train_test_split(X,y,test_size=.33,random_state=r_state)
    rf = RandomForestRegressor()
    rf.fit(X_train,y_train)
    rf_pred = rf.predict(x_test)
    r2_scr = r2_score(y_test,rf_pred)
    if r2_scr>max_rf_score:
        max_rf_score=r2_scr
        final_r_state = r_state
        
print('max r2_score for the given ','', final_r_state, 'is', max_rf_score)
# Out:
# max r2_score for the given   74 is 0.8554378107214271

# %%
#creating a model using Random Forest Regression
X_train,x_test,y_train,y_test= train_test_split(X,y,test_size=.33,random_state=74)
print('X_train shape:', X_train.shape)
print('x_test shape:', x_test.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (104, 6)
# x_test shape: (52, 6)
# y_train shape: (104,)
# y_test shape: (52,)

# %%
rf = RandomForestRegressor()
rf_model = rf.fit(X_train,y_train)
rf_model
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_pred = rf.predict(x_test)
rf_pred
# Out:
# array([6.43357, 4.03514, 4.78909, 6.47279, 3.89947, 4.73509, 5.07753,
#        5.5335 , 4.4665 , 3.77223, 6.74272, 5.85091, 5.70808, 6.86257,
#        4.61093, 4.47767, 6.04111, 6.25924, 4.734  , 4.66782, 4.13939,
#        5.96069, 3.57669, 5.66846, 5.90668, 6.62617, 7.27619, 6.38933,
#        4.49918, 5.7096 , 7.49262, 5.82675, 5.63812, 5.83044, 4.27037,
#        6.51705, 7.2856 , 6.94879, 4.87482, 5.04301, 5.98293, 6.82179,
#        4.06676, 4.32812, 7.34409, 4.22503, 7.03107, 5.32652, 6.34634,
#        5.85629, 5.19214, 6.3958 ])

# %%
rf_R2_score = r2_score(y_test,rf_pred)
rf_R2_score
# Out:
# 0.8547442017500301

# %%
rf_MSE = mean_squared_error(y_test,rf_pred)
rf_MSE
# Out:
# 0.17195262140961576

# %%
rf_MAE = mean_absolute_error(y_test,rf_pred)
rf_MAE
# Out:
# 0.3269817307692312

# %%
rf_RMSE = sqrt(rf_MSE)
rf_RMSE
# Out:
# 0.4146717031696469

# %%
#saving the model
from sklearn.externals import joblib
joblib.dump(rf_pred,'Happiness.pkl')
# Out:
# ['Happiness.pkl']
